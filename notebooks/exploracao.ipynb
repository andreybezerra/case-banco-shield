# %% [markdown]
# Imports e Configuração de Ambiente

# %%
import pandas as pd
import duckdb


root_directory = "/workspaces/andreybezerra--case-banco-shield"

fact_contract_directory = root_directory + "/data/raw/fato_contratos.csv"
dim_product_directory = root_directory + "/data/raw/dim_produto.csv"
dim_locality_directory = root_directory + "/data/raw/dim_localidade.csv"

# %% [markdown]
# Dataframes

# %%
df_fact_contracts = pd.read_csv(fact_contract_directory)
df_dim_product = pd.read_csv(dim_product_directory)
df_dim_locality = pd.read_csv(dim_locality_directory)

# %% [markdown]
# Análise e Exploração

# %%
dim_product = duckdb.sql("""
SELECT
    *
FROM
    df_dim_product
""").show()
# Out:
# ┌────────────┬────────────────────────────────┬───────────────┬──────────────┬───────────────┐
# │ product_id │          product_name          │   category    │ tenor_months │ base_rate_apr │
# │   int64    │            varchar             │    varchar    │    int64     │    double     │
# ├────────────┼────────────────────────────────┼───────────────┼──────────────┼───────────────┤
# │       1001 │ Cartão Vibranium               │ Conta         │           60 │        0.2634 │
# │       1002 │ Financiamento Quinjet          │ Seguro        │           24 │        0.2822 │
# │       1003 │ Consórcio Stark                │ Empréstimo    │           48 │        0.1511 │
# │       1004 │ Seguro Asgard                  │ Conta         │           24 │        0.2858 │
# │       1005 │ Empréstimo Arc Reactor         │ Consórcio     │           48 │        0.1809 │
# │       1006 │ Leasing Hulkbuster             │ Investimentos │           60 │        0.1556 │
# ...

# %%
dim_locality = duckdb.sql("""
SELECT
    *
FROM
    df_dim_locality
""").show()
# Out:
# ┌─────────────┬────────────────┬───────────────┬────────────────────┐
# │ location_id │ location_name  │ macro_region  │ risk_factor_region │
# │    int64    │    varchar     │    varchar    │       double       │
# ├─────────────┼────────────────┼───────────────┼────────────────────┤
# │         501 │ Nova York      │ Norte América │              1.034 │
# │         502 │ Wakanda        │ África        │              1.046 │
# │         503 │ Nova Asgard    │ Europa        │              0.883 │
# │         504 │ Sokovia        │ Europa        │              1.236 │
# │         505 │ Xandar         │ Galáxia       │              1.149 │
# │         506 │ Knowhere       │ Galáxia       │              1.223 │
# │         507 │ Sanctum SP     │ Brasil        │              1.203 │
# │         508 │ Rio de Janeiro │ Brasil        │              1.069 │
# │         509 │ São Paulo      │ Brasil        │              1.215 │
# ...

# %%
fact_contracts = duckdb.sql("""
SELECT
    *
FROM
    df_fact_contracts
""").show()
# Out:
# ┌───────────────────┬─────────┬──────────────┬────────────┬─────────────┬───────┬─────────────────┬─────────────────────┬───────┬───────────────────────┬────────────┐
# │    contract_id    │ ano_mes │     bank     │ product_id │ location_id │ units │ financed_amount │ outstanding_balance │  dpd  │ delinquent_amount_30p │ risk_score │
# │      varchar      │  int64  │   varchar    │   double   │    int64    │ int64 │     double      │       double        │ int64 │        double         │   double   │
# ├───────────────────┼─────────┼──────────────┼────────────┼─────────────┼───────┼─────────────────┼─────────────────────┼───────┼───────────────────────┼────────────┤
# │ C202501-BA-000001 │  202501 │ Banco Shield │     1013.0 │         509 │     1 │        24668.11 │            19184.31 │     0 │                   0.0 │     0.0842 │
# ...

# %%
fact_contracts = duckdb.sql("""
SELECT
    *
FROM
    df_fact_contracts
WHERE
    product_id  IS NULL
""").show()
# Out:
# ┌───────────────────┬─────────┬──────────────┬────────────┬─────────────┬───────┬─────────────────┬─────────────────────┬───────┬───────────────────────┬────────────┐
# │    contract_id    │ ano_mes │     bank     │ product_id │ location_id │ units │ financed_amount │ outstanding_balance │  dpd  │ delinquent_amount_30p │ risk_score │
# │      varchar      │  int64  │   varchar    │   double   │    int64    │ int64 │     double      │       double        │ int64 │        double         │   double   │
# ├───────────────────┼─────────┼──────────────┼────────────┼─────────────┼───────┼─────────────────┼─────────────────────┼───────┼───────────────────────┼────────────┤
# │ C202502-BA-000673 │  202502 │ Banco Shield │       NULL │         507 │     1 │        35814.85 │            26716.02 │     0 │                   0.0 │     0.0845 │
# ...

# %%
fact_contracts = duckdb.sql("""
SELECT
    *
FROM
    df_fact_contracts
WHERE
    location_id IS NULL
""").show()
# Out:
# ┌─────────────┬─────────┬─────────┬────────────┬─────────────┬───────┬─────────────────┬─────────────────────┬───────┬───────────────────────┬────────────┐
# │ contract_id │ ano_mes │  bank   │ product_id │ location_id │ units │ financed_amount │ outstanding_balance │  dpd  │ delinquent_amount_30p │ risk_score │
# │   varchar   │  int64  │ varchar │   double   │    int64    │ int64 │     double      │       double        │ int64 │        double         │   double   │
# ├─────────────┴─────────┴─────────┴────────────┴─────────────┴───────┴─────────────────┴─────────────────────┴───────┴───────────────────────┴────────────┤
# │                                                                         0 rows                                                                          │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
fact_contracts = duckdb.sql("""
                            SELECT
                                *
                            FROM
                                df_fact_contracts a
                            INNER JOIN df_dim_product b ON a.product_id = b.product_id
                            INNER JOIN df_dim_locality c ON a.location_id = c.location_id
                        """).show()
# Out:
# ┌───────────────────┬─────────┬──────────────┬────────────┬─────────────┬───────┬─────────────────┬─────────────────────┬───────┬───────────────────────┬────────────┬────────────┬────────────────────────┬───────────────┬──────────────┬───────────────┬─────────────┬────────────────┬───────────────┬────────────────────┐
# │    contract_id    │ ano_mes │     bank     │ product_id │ location_id │ units │ financed_amount │ outstanding_balance │  dpd  │ delinquent_amount_30p │ risk_score │ product_id │      product_name      │   category    │ tenor_months │ base_rate_apr │ location_id │ location_name  │ macro_region  │ risk_factor_region │
# │      varchar      │  int64  │   varchar    │   double   │    int64    │ int64 │     double      │       double        │ int64 │        double         │   double   │   int64    │        varchar         │    varchar    │    int64     │    double     │    int64    │    varchar     │    varchar    │       double       │
# ...
